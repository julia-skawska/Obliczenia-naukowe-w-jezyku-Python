# %% [markdown]
# ## Importy

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ##Exe 10.1

# %% [markdown]
# python -m venv sci_comp_py <br>
# sci_comp_py\Scripts\activate <br>
# pip install numpy matplotlib pandas

# %% [markdown]
# ## Exe 10.2

# %%
dates = np.array(pd.date_range("2026-05-01", "2026-05-31"), dtype="datetime64[D]")
temp = np.round(np.random.uniform(-9, 35, len(dates)), 1)
temp_df = pd.Series(temp, index=dates, name="Temperature at noon")

# %%
print(temp_df)
# Out:
# 2026-05-01    22.5
# 2026-05-02    34.8
# 2026-05-03    25.2
# 2026-05-04    16.7
# 2026-05-05    14.2
# 2026-05-06     3.8
# 2026-05-07    24.0
# 2026-05-08    14.3
# 2026-05-09    -6.6
# 2026-05-10     4.4
# 2026-05-11    17.7
# 2026-05-12    -4.7
# 2026-05-13    29.5
# 2026-05-14    17.3
# 2026-05-15    -5.6
# 2026-05-16    10.2
# 2026-05-17    -8.0
# 2026-05-18    14.7
# 2026-05-19    -4.8
# 2026-05-20    25.0
# 2026-05-21     7.4
# 2026-05-22     1.2
# 2026-05-23    23.4
# 2026-05-24    33.8
# 2026-05-25    28.1
# 2026-05-26    13.2
# 2026-05-27     5.2
# 2026-05-28    28.8
# 2026-05-29     7.3
# 2026-05-30     7.2
# 2026-05-31    29.7
# Name: Temperature at noon, dtype: float64

# %% [markdown]
# ## Exe 10.3

# %%
data = [
    ["Hydrogen", "H", 1.008],
    ["Helium", "He", 4.0026],
    ["Lithium", "Li", 6.94],
    ["Berylium", "Be", 9.0122],
    ["Boron", "B", 10.81],
    ["Carbon", "C", 12.011],
    ["Nitrogen", "N", 14.007],
    ["Oxygen", "O", 15.999],
    ["Fluorine", "F", 18.998],
    ["Neon", "Ne", 20.180]]

df = pd.DataFrame(data, columns=["Name", "Symbol", "Weight"], index=range(1, 11))
print(df)
# Out:
#          Name Symbol   Weight
# 1    Hydrogen      H   1.0080
# 2      Helium     He   4.0026
# 3     Lithium     Li   6.9400
# 4   Beryllium     Be   9.0122
# 5       Boron      B  10.8100
# 6      Carbon      C  12.0110
# 7    Nitrogen      N  14.0070
# 8      Oxygen      O  15.9990
# 9    Fluorine      F  18.9980
# 10       Neon     Ne  20.1800
